# %% [markdown]
# # BAB 2 TUTORIAL MATPLOTLIB PEMULA

# %%
import numpy as np 
import matplotlib.pyplot as plt

# %%
# Bikin data acak berantai (kumulatif) biar trennya naik-turun kayak saham
data = np.random.randn(50,).cumsum()

# %%
# 1. membuat kanvas kosong
fig = plt.figure()

# 2. Bagi area jadi grid 2x2, lalu plot kertas di slot 1, 2, dan 3 (BaKoS)
ax1 = fig.add_subplot(2,2,1) # Kiri Atas
ax2 = fig.add_subplot(2,2,2) # Kanan Atas
ax3 = fig.add_subplot(2,2,3) # Kiri Bawah (Slot 4 Kanan Bawah kosong)

# 4. Gambar datanya di tiap kertas dengan style berbeda
ax1.plot(data, 'k--') # k=Hitam, -- = putus-putus
ax2.plot(data, 'r-')  # r=Merah, - = garis lurus
ax3.plot(data, 'b')   # b=Biru, (tanpa simbol = garis lurus)

plt.show() #menampilkan grafik

# %% [markdown]
# # WARNA, TANDA, & GAYA GARIS

# %%
# Plot dengan **label='Default'** — label dipake buat legend nanti.
plt.plot(data, 'k--', label='Default')

plt.plot(data, 
         'k-', 
         drawstyle='steps-post', 
         label='Stepwise')

plt.legend() #memberi nama / tanda

# %% [markdown]
# ### Sama kayak atas plus plt.legend() buat munculin kotak legenda di lokasi terbaik (loc='best').

# %%
plt.plot(data, 'k-', 
         drawstyle='steps-post', 
         label='Stepwise')
plt.legend(loc='best')

# %% [markdown]
# # Ketebalan, Label dan Legenda

# %%
fig = plt.figure()  
ax = fig.add_subplot(1,1,1)

# 1. Gambar grafik utama dari data kamu
ax.plot(data)

# 2. Tentukan posisi "paku" pembatas di sumbu X (angka mana aja yg mau dimunculin)
location = ax.set_xticks([0, 10, 20, 30, 40, 50])

# 3. Ganti angka "paku" tadi jadi tulisan, miringkan 30 derajat biar gak tabrakan
label = ax.set_xticklabels(
    ["one", "two", "three", "four", "five", "six"], 
    rotation=30, 
    fontsize="small"
)

# 4. Kasih nama judul grafik, label sumbu X (bawah), dan sumbu Y (kiri)
ax.set_title('First Graph')
ax.set_xlabel('Stages')
ax.set_ylabel('Anything')
# Out:
# Text(0, 0.5, 'Anything')

# %% [markdown]
# # Anatosi dan gambar pada Subplot

# %%
import pandas as pd 

df = pd.read_csv('DATASET/FB.csv')
df.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2018-07-30  175.300003  175.300003  166.559998  171.059998  171.059998
# 1  2018-07-31  170.669998  174.240005  170.000000  172.580002  172.580002
# 2  2018-08-01  173.929993  175.080002  170.899994  171.649994  171.649994
# 3  2018-08-02  170.679993  176.789993  170.270004  176.369995  176.369995
# 4  2018-08-03  177.690002  178.850006  176.149994  177.779999  177.779999
#
#      Volume
# 0  65280800
# 1  40356500
# 2  34042100
# 3  32400000
# 4  24763400

# %%
# Load lagi tapi pake kolom 0 sebagai index & parse jadi datetime — biar bisa diquery by date.
df=pd.read_csv('DATASET/FB.csv', 
               index_col=0, 
               parse_dates=True)
df.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-07-30  175.300003  175.300003  166.559998  171.059998  171.059998
# 2018-07-31  170.669998  174.240005  170.000000  172.580002  172.580002
# 2018-08-01  173.929993  175.080002  170.899994  171.649994  171.649994
# 2018-08-02  170.679993  176.789993  170.270004  176.369995  176.369995
# 2018-08-03  177.690002  178.850006  176.149994  177.779999  177.779999
#
#               Volume
# Date
# 2018-07-30  65280800
# 2018-07-31  40356500
# 2018-08-01  34042100
# 2018-08-02  32400000
# 2018-08-03  24763400

# %%
# cari harga min 
c_price.min()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 2
#       1 # cari harga min
# ----> 2 c_price.min()
#
# NameError: name 'c_price' is not defined

# %%
# Otomatis mencari tanggal di mana harga saham berada di titik paling rendah
date_minimum = c_price.idxmin()

print(date_minimum)
# Output otomatis keluar: '2018-12-24'
# Out:
# 2018-12-24 00:00:00

# %%
# --- 1. MENYIAPKAN KANVAS KOSONG ---
# Membuat objek gambar (fig) dan area plot (ax)
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

# --- 2. MENGGAMBAR GARIS SAHAM ---
# Menggambar data c_price ke kanvas 'ax' dengan garis hitam solid ('k-')
c_price.plot(ax=ax, style='k-')

# --- 3. MEMBERI JUDUL GRAFIK ---
ax.set_title('Facebook stock closing prices')

# --- 4. MENYIAPKAN ANOTASI ---
# Menentukan tanggal minimum dan teks penanda
date = "2018-12-24"
text = "Minimum"

# --- 5. MEMBUAT PANAH MERAH (ANOTASI) ---
ax.annotate(
    text,                      # Teks yang mau ditampilkan ("Minimum")
    xy=(date, 125),            # Ujung anak panah menunjuk ke koordinat ini
    xytext=(date, 150),        # Posisi teks "Minimum" diletakkan
    arrowprops=dict(facecolor='red') # Mengatur warna panah menjadi merah
)

# --- 6. MENAMPILKAN HASILNYA ---
plt.show()
